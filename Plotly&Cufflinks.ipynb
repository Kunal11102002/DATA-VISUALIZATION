# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunal11102002/DATA-VISUALIZATION/blob/main/Plotly%26Cufflinks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot
import plotly.graph_objects as go

# %% [markdown]
# Plotly is a powerful open-source graphing library that allows you to create interactive, publication-quality graphs online. It supports various types of charts like line plots, scatter plots, bar charts, 3D plots, and more.
#
# Cufflinks is a library that connects Pandas DataFrames to Plotly. It makes it very easy to create Plotly visualizations directly from Pandas DataFrames with just a single line of code, simplifying the data visualization process significantly.

# %%
tips = sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from plotly.io import show
fig = go.Figure(data=go.Scatter(y=tips['total_bill'], mode='lines', line=dict(color='orange')))
show(fig)
# Out:
# <div>                            <div id="8c6e06cc-77d5-4522-9a63-b0baa69be786" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c6e06cc-77d5-4522-9a63-b0baa69be786")) {                    Plotly.newPlot(                        "8c6e06cc-77d5-4522-9a63-b0baa69be786",                        [{"line":{"color":"orange"},"mode":"lines","y":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,22.23,32.4,28.55,18.04,12.54,10.29,34.81,9.94,25.56,19.49,38.01,26.41,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,16.45,3.07,20.23,15.01,12.02,17
# ...

# %%
grouped_data = tips.groupby('day', observed=False)['tip'].mean().reset_index()
fig = go.Figure(data=go.Bar(x=grouped_data['day'], y=grouped_data['tip'], marker_color='lightblue'))
fig.update_layout(title='Average Tip by Day', xaxis_title='Day', yaxis_title='Average Tip')
fig.show()
# Out:
# <div>                            <div id="7bc931fd-4bee-4761-97b4-fbec6c8c3060" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc931fd-4bee-4761-97b4-fbec6c8c3060")) {                    Plotly.newPlot(                        "7bc931fd-4bee-4761-97b4-fbec6c8c3060",                        [{"marker":{"color":"lightblue"},"x":["Thur","Fri","Sat","Sun"],"y":[2.7714516129032254,2.734736842105263,2.993103448275862,3.2551315789473683],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555555
# ...

# %%
fig_scatter = go.Figure(data=[go.Scatter(x=tips['total_bill'], y=tips['tip'], mode='markers')])
fig_scatter.update_layout(title='Total Bill vs. Tip')
fig_scatter.show()

fig_box = go.Figure(data=[go.Box(x=tips['day'], y=tips['total_bill'])])
fig_box.update_layout(title='Total Bill by Day')
fig_box.show()
# Out:
# <div>                            <div id="05a15bb6-9082-49fd-9aae-c0363f145b38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05a15bb6-9082-49fd-9aae-c0363f145b38")) {                    Plotly.newPlot(                        "05a15bb6-9082-49fd-9aae-c0363f145b38",                        [{"mode":"markers","x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30.4,18.29,22.23,32.4,28.55,18.04,12.54,10.29,34.81,9.94,25.56,19.49,38.01,26.41,11.24,48.27,20.29,13.81,11.02,18.29,17.59,20.08,16.45,3.07,20.23,15.01,12.02,17.07,26.86,25.28,14.73,10
# ...
